# %%
# %tensorflow_version 1.x
import tensorflow as tf
import tensorflow_hub as hub
import numpy as np
import pandas as pd
from sklearn.model_selection import train_test_split

# %%
tf.test.is_gpu_available()
# Out:
# True

# %%
# !pip install contractions
# Out:
# Collecting contractions
#   Downloading https://files.pythonhosted.org/packages/5a/6a/7bde208d21b4f7db1b666739dca8826d8fd7af34a14fddfda9b597ab8a45/contractions-0.0.23-py2.py3-none-any.whl
# Collecting textsearch
#   Downloading https://files.pythonhosted.org/packages/42/a8/03407021f9555043de5492a2bd7a35c56cc03c2510092b5ec018cae1bbf1/textsearch-0.0.17-py2.py3-none-any.whl
# Collecting pyahocorasick
#   Downloading https://files.pythonhosted.org/packages/f4/9f/f0d8e8850e12829eea2e778f1c90e3c53a9a799b7f412082a5d21cd19ae1/pyahocorasick-1.4.0.tar.gz (312kB)
#      |████████████████████████████████| 317kB 5.0MB/s
# Collecting Unidecode
#   Downloading https://files.pythonhosted.org/packages/d0/42/d9edfed04228bacea2d824904cae367ee9efd05e6cce7ceaaedd0b0ad964/Unidecode-1.1.1-py2.py3-none-any.whl (238kB)
#      |████████████████████████████████| 245kB 39.0MB/s
# Building wheels for collected packages: pyahocorasick
#   Building wheel for pyahocorasick (setup.py) ... done
#   Created wheel for pyahocorasick: filename=pyahocorasick-1.4.0-cp36-cp36m-linux_x86_64.whl size=81702 sha256=8c860958b0c37c2bb2e815e1ba2af3ac4811c4de8a264a63dd2098fb3c5a4c52
#   Stored in directory: /root/.cache/pip/wheels/0a/90/61/87a55f5b459792fbb2b7ba6b31721b06ff5cf6bde541b40994
# Successfully built pyahocorasick
# Installing collected packages: pyahocorasick, Unidecode, textsearch, contractions
# Successfully installed Unidecode-1.1.1 contractions-0.0.23 pyahocorasick-1.4.0 textsearch-0.0.17

# %%
import contractions
from bs4 import BeautifulSoup
import unicodedata
import re

# %%
def strip_html_tags(text):
    soup = BeautifulSoup(text, "html.parser")
    [s.extract() for s in soup(['iframe', 'script'])]
    stripped_text = soup.get_text()
    stripped_text = re.sub(r'[\r|\n|\r\n]+', '\n', stripped_text)
    return stripped_text


def remove_accented_chars(text):
    text = unicodedata.normalize('NFKD', text).encode('ascii', 'ignore').decode('utf-8', 'ignore')
    return text


def expand_contractions(text):
    return contractions.fix(text)



def remove_special_characters(text, remove_digits=False):
    pattern = r'[^a-zA-Z0-9\s]' if not remove_digits else r'[^a-zA-Z\s]'
    text = re.sub(pattern, '', text)
    return text


def pre_process_document(document):
    
    # strip HTML
    document = strip_html_tags(document)
    
    # lower case
    document = document.lower()
    
    # remove extra newlines (often might be present in really noisy text)
    document = document.translate(document.maketrans("\n\t\r", "   "))
    
    # remove accented characters
    document = remove_accented_chars(document)
    
    # expand contractions    
    document = expand_contractions(document)
               
    # remove special characters and\or digits    
    # insert spaces between special characters to isolate them    
    special_char_pattern = re.compile(r'([{.(-)!}])')
    document = special_char_pattern.sub(" \\1 ", document)
    document = remove_special_characters(document, remove_digits=True)  
        
    # remove extra whitespace
    document = re.sub(' +', ' ', document)
    document = document.strip()
    
    return document


pre_process_corpus = np.vectorize(pre_process_document)

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Go to this URL in a browser: https://accounts.google.com/o/oauth2/auth?client_id=947318989803-6bn6qk8qdgf4n4g3pfee6491hc0brc4i.apps.googleusercontent.com&redirect_uri=urn%3aietf%3awg%3aoauth%3a2.0%3aoob&response_type=code&scope=email%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdocs.test%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdrive%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdrive.photos.readonly%20https%3a%2f%2fwww.googleapis.com%2fauth%2fpeopleapi.readonly
#
# Enter your authorization code:
# ··········
# Mounted at /content/drive

# %%
local_data_path = '/content/drive/My Drive/ColabNotebooks/winereview/' # change as needed
reviews = pd.read_csv(local_data_path+"winemag-data-130k-v2.csv")
def point_assign(x):
  if x <= 85:
    return 0
  elif x <= 90:
    return 1
  elif x <=95:
    return 2
  else:
    return 3
reviews["points_cat"] = reviews["points"].apply(point_assign)

# %%
pre_reviews = reviews['description'].values

# %%
post_reviews = pre_process_corpus(pre_reviews)

# %%
post_reviews[14343]
# Out:
# 'this rhonestyle blend is harsh and rugged with unripe mintiness but it has enough cherry berry and mocha flavors to pass'

# %%
X = post_reviews
y = reviews['points_cat'].values
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.5, random_state=0)

# %%
print(X[9779])
print(y[9779])
print(len(X_train))
# Out:
# since we last tried this wine catena has dialed back the new oak and pumped up the natural acidity and the result is pleasantly akin to fine burgundy now the emphasis is on refined dijonstyle apple and peach flavors with great mouthfeel drink now
# 2
# 64985

# %%
# Training input on the whole training set with no limit on training epochs.
train_input_fn = tf.estimator.inputs.numpy_input_fn(
    {'sentence': X}, y,
    batch_size=32, num_epochs=None, shuffle=True)

# %%
# Prediction on the whole training set.
predict_train_input_fn = tf.estimator.inputs.numpy_input_fn(
    {'sentence': X_train}, y_train, shuffle=False)

# %%
# Prediction on the test set.
predict_test_input_fn = tf.estimator.inputs.numpy_input_fn(
    {'sentence': X_test}, y_test, shuffle=False)

# %%
embedding_feature = hub.text_embedding_column(
    key='sentence', 
    module_spec="https://tfhub.dev/google/universal-sentence-encoder/2", #https://tfhub.dev/google/nnlm-en-dim128/2
    trainable=True) # change to True

# %%
dnn = tf.estimator.DNNClassifier(
          hidden_units=[256, 64],
          feature_columns=[embedding_feature],
          n_classes=4,
          activation_fn=tf.nn.relu,
          dropout=0.1,
          optimizer=tf.train.AdamOptimizer(learning_rate=0.001))
# Out:
# INFO:tensorflow:Using default config.
# INFO:tensorflow:Using default config.
# WARNING:tensorflow:Using temporary folder as model directory: /tmp/tmp8kx5p9u1
# WARNING:tensorflow:Using temporary folder as model directory: /tmp/tmp8kx5p9u1
# INFO:tensorflow:Using config: {'_model_dir': '/tmp/tmp8kx5p9u1', '_tf_random_seed': None, '_save_summary_steps': 100, '_save_checkpoints_steps': None, '_save_checkpoints_secs': 600, '_session_config': allow_soft_placement: true
# graph_options {
#   rewrite_options {
#     meta_optimizer_iterations: ONE
#   }
# }
# , '_keep_checkpoint_max': 5, '_keep_checkpoint_every_n_hours': 10000, '_log_step_count_steps': 100, '_train_distribute': None, '_device_fn': None, '_protocol': None, '_eval_distribute': None, '_experimental_distribute': None, '_experimental_max_worker_delay_secs': None, '_session_creation_timeout_secs': 7200, '_service': None, '_cluster_spec': <tensorflow.python.training.server_lib.ClusterSpec object at 0x7fbb7f8ba7f0>, '_task_type': 'worker', '_task_id': 0, '_global_id_in_cluster': 0, '_master': '', '_evaluation_master': '', '_is_chief': True, '_num_ps_replicas': 0, '_num_worker_replicas': 1}
# INFO:tensorflow:Using config: {'_model_dir': '/tmp/tmp8kx5p9u1', '_tf_random_seed': None, '_save_summary_steps': 100, '_save_checkpoints_steps': None, '_save_checkpoints_secs': 600, '_session_config': allow_soft_placement: true
# graph_options {
#   rewrite_options {
#     meta_optimizer_iterations: ONE
#   }
# }
# , '_keep_checkpoint_max': 5, '_keep_checkpoint_every_n_hours': 10000, '_log_step_count_steps': 100, '_train_distribute': None, '_device_fn': None, '_protocol': None, '_eval_distribute': None, '_experimental_distribute': None, '_experimental_max_worker_delay_secs': None, '_session_creation_timeout_secs': 7200, '_service': None, '_cluster_spec': <tensorflow.python.training.server_lib.ClusterSpec object at 0x7fbb7f8ba7f0>, '_task_type': 'worker', '_task_id': 0, '_global_id_in_cluster': 0, '_master': '', '_evaluation_master': '', '_is_chief': True, '_num_ps_replicas': 0, '_num_worker_replicas': 1}

# %%
tf.logging.set_verbosity(tf.logging.ERROR)
import time

TOTAL_STEPS = 10000
STEP_SIZE = 1000
for step in range(0, TOTAL_STEPS+1, STEP_SIZE):
    print()
    print('-'*100)
    print('Training for step =', step)
    start_time = time.time()
    dnn.train(input_fn=train_input_fn, steps=STEP_SIZE)
    elapsed_time = time.time() - start_time
    print('Train Time (s):', elapsed_time)
    print('Eval Metrics (Train):', dnn.evaluate(input_fn=predict_train_input_fn))
    print('Eval Metrics (Testing):', dnn.evaluate(input_fn=predict_test_input_fn))
# Out:
# ----------------------------------------------------------------------------------------------------
# Training for step = 0
# Train Time (s): 228.2736577987671
# Eval Metrics (Train): {'accuracy': 0.75769794, 'average_loss': 0.59309584, 'loss': 75.870735, 'global_step': 1000}
# Eval Metrics (Testing): {'accuracy': 0.7581633, 'average_loss': 0.59280556, 'loss': 75.83477, 'global_step': 1000}
#
# ----------------------------------------------------------------------------------------------------
# Training for step = 1000
# Train Time (s): 230.15993428230286
# Eval Metrics (Train): {'accuracy': 0.80903286, 'average_loss': 0.5178559, 'loss': 66.2458, 'global_step': 2000}
# Eval Metrics (Testing): {'accuracy': 0.8081587, 'average_loss': 0.5190438, 'loss': 66.39878, 'global_step': 2000}
#
# ----------------------------------------------------------------------------------------------------
# Training for step = 2000
# Train Time (s): 230.0328814983368
# Eval Metrics (Train): {'accuracy': 0.8289759, 'average_loss': 0.4660596, 'loss': 59.619846, 'global_step': 3000}
# Eval Metrics (Testing): {'accuracy': 0.83293325, 'average_loss': 0.46263275, 'loss': 59.18239, 'global_step': 3000}
#
# ----------------------------------------------------------------------------------------------------
# Training for step = 3000
# Train Time (s): 229.09198093414307
# Eval Metrics (Train): {'accuracy': 0.85544354, 'average_loss': 0.41694376, 'loss': 53.336792, 'global_step': 4000}
# Eval Metrics (Testing): {'accuracy': 0.858985, 'average_loss': 0.41335276, 'loss': 52.878235, 'global_step': 4000}
#
# ----------------------------------------------------------------------------------------------------
# Training for step = 4000
# Train Time (s): 229.81986474990845
# Eval Metrics (Train): {'accuracy': 0.8632146, 'average_loss': 0.4829769, 'loss': 61.783966, 'global_step': 5000}
# Eval Metrics (Testing): {'accuracy': 0.8661404, 'average_loss': 0.4779563, 'loss': 61.142654, 'global_step': 5000}
#
# ----------------------------------------------------------------------------------------------------
# Training for step = 5000
# Train Time (s): 229.68730330467224
# Eval Metrics (Train): {'accuracy': 0.8924059, 'average_loss': 0.31512713, 'loss': 40.31208, 'global_step': 6000}
# Eval Metrics (Testing): {'accuracy': 0.8966239, 'average_loss': 0.30885947, 'loss': 39.510906, 'global_step': 6000}
#
# ----------------------------------------------------------------------------------------------------
# Training for step = 6000
# Train Time (s): 229.95131015777588
# Eval Metrics (Train): {'accuracy': 0.8997153, 'average_loss': 0.3453185, 'loss': 44.17426, 'global_step': 7000}
# Eval Metrics (Testing): {'accuracy': 0.9025944, 'average_loss': 0.33666605, 'loss': 43.06807, 'global_step': 7000}
#
# ----------------------------------------------------------------------------------------------------
# Training for step = 7000
# Train Time (s): 229.2554121017456
# Eval Metrics (Train): {'accuracy': 0.9131492, 'average_loss': 0.40405118, 'loss': 51.68753, 'global_step': 8000}
# Eval Metrics (Testing): {'accuracy': 0.9154741, 'average_loss': 0.3956393, 'loss': 50.612236, 'global_step': 8000}
#
# ----------------------------------------------------------------------------------------------------
# Training for step = 8000
# Train Time (s): 229.86605620384216
# Eval Metrics (Train): {'accuracy': 0.88882047, 'average_loss': 0.49656025, 'loss': 63.521587, 'global_step': 9000}
# Eval Metrics (Testing): {'accuracy': 0.890361, 'average_loss': 0.49310637, 'loss': 63.080727, 'global_step': 9000}
#
# ----------------------------------------------------------------------------------------------------
# Training for step = 9000
# Train Time (s): 233.0245385169983
# Eval Metrics (Train): {'accuracy': 0.92999923, 'average_loss': 0.1852428, 'loss': 23.696857, 'global_step': 10000}
# Eval Metrics (Testing): {'accuracy': 0.93195456, 'average_loss': 0.17818014, 'loss': 22.79373, 'global_step': 10000}
#
# ----------------------------------------------------------------------------------------------------
# Training for step = 10000
# Train Time (s): 230.34590935707092
# Eval Metrics (Train): {'accuracy': 0.92933756, 'average_loss': 0.19687328, 'loss': 25.184664, 'global_step': 11000}
# Eval Metrics (Testing): {'accuracy': 0.9295079, 'average_loss': 0.19478297, 'loss': 24.91765, 'global_step': 11000}

# %%
def get_predictions(estimator, input_fn):
    return [x["class_ids"][0] for x in estimator.predict(input_fn=input_fn)]

# %%
y_test_predict = get_predictions(estimator=dnn, input_fn=predict_test_input_fn)

# %%
len(y_test_predict)
# Out:
# 64986

# %%
from sklearn.metrics import precision_recall_fscore_support, confusion_matrix

# %%
confusion_matrix(y_test, y_test_predict)
# Out:
# array([[10079,   845,     8,     0],
#        [  897, 35469,   935,     2],
#        [    8,  1745, 14545,    11],
#        [    0,     1,   129,   312]])

# %%
precision_recall_fscore_support(y_test, y_test_predict, average='weighted')
# Out:
# (0.9295638666008623, 0.9295078940079402, 0.9292411816485074, None)

# %%
exportcsv = pd.DataFrame({'Review': X_test, 'Class': y_test, 'Predict': y_test_predict})

# %%
exportcsv.to_csv('/content/drive/My Drive/ColabNotebooks/winereview/testoutput_use.csv')
